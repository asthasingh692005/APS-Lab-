# %% [markdown]
# <a href="https://colab.research.google.com/github/asthasingh692005/APS-Lab-/blob/main/lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Searching
# Implement Linear Search. Determine the time required to search for element. Repeat the experiment for different values of n, the number of elements in the list to besearched and plot a graph of the time taken versus n.
#
# - To implement Linear Search, measure its time complexity for searching an element, vary the input size by changing the number of elements in the list, and plot a graph to visualize the relationship between time taken and input size
# - Algorithm:
# 1. Start with the first element of the list.
# 2. Compare the element with the value being searched for.
# 3. If the element matches, return the index.
# 4. If the element does not match, move to the next element and repeat steps 2-3.
# 5. If the end of the list is reached and no match is found, return -1

# %% [markdown]
# - **Created by Dr. Ajay

# %%
# write code for Linear Search and plot a graph to visualize the relationship between time taken and input size

# %%
import time
import random
import matplotlib.pyplot as plt

def linear_search(arr, target):
    """Implements the linear search algorithm."""
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1

# Initialize lists to store results
input_sizes = []
times_taken = []

# Set up experiment parameters
min_n = 1000
max_n = 100000
step_n = 5000

print(f"Running linear search experiment from n={min_n} to n={max_n} with step {step_n}...")

# Loop through different input sizes
for n in range(min_n, max_n + 1, step_n):
    # Generate a sorted list of n random integers
    # Sorting is not strictly necessary for linear search but helps with consistency for comparisons
    # The values are chosen to be within a range to prevent very large numbers
    test_list = sorted([random.randint(0, n * 2) for _ in range(n)])

    # Choose a target element to search for
    # We'll search for an element known to be in the list for consistent measurement
    target_element = test_list[random.randint(0, n - 1)]

    # Record the start time
    start_time = time.perf_counter()

    # Call the linear_search function
    linear_search(test_list, target_element)

    # Record the end time
    end_time = time.perf_counter()

    # Calculate elapsed time
    elapsed_time = end_time - start_time

    # Append results
    input_sizes.append(n)
    times_taken.append(elapsed_time)

    print(f"n = {n}, Time = {elapsed_time:.6f} seconds")

print("Experiment completed. Data collected for plotting.")

# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(input_sizes, times_taken, marker='o', linestyle='-', color='b')
plt.title('Linear Search Time Complexity')
plt.xlabel('Input Size (n)')
plt.ylabel('Time Taken (seconds)')
plt.grid(True)
plt.show()
# Out:
# Running linear search experiment from n=1000 to n=100000 with step 5000...
# n = 1000, Time = 0.000019 seconds
# n = 6000, Time = 0.000203 seconds
# n = 11000, Time = 0.000233 seconds
# n = 16000, Time = 0.000916 seconds
# n = 21000, Time = 0.000891 seconds
# n = 26000, Time = 0.001067 seconds
# n = 31000, Time = 0.001674 seconds
# n = 36000, Time = 0.003261 seconds
# n = 41000, Time = 0.007764 seconds
# n = 46000, Time = 0.000106 seconds
# n = 51000, Time = 0.003302 seconds
# n = 56000, Time = 0.002912 seconds
# n = 61000, Time = 0.004568 seconds
# n = 66000, Time = 0.002017 seconds
# n = 71000, Time = 0.011107 seconds
# n = 76000, Time = 0.007577 seconds
# n = 81000, Time = 0.005380 seconds
# n = 86000, Time = 0.002861 seconds
# n = 91000, Time = 0.003404 seconds
# n = 96000, Time = 0.007582 seconds
# Experiment completed. Data collected for plotting.

# %% [markdown]
# # 2. Searching
# Implement recursive Binary Search. Determine the time required to search an element.Repeat the experiment for different values of n, the number of elements in the list to besearched and plot a graph of the time taken versus n.
# - implement recursive Binary Search, measure its time complexity for searching an element and plot a graph of time taken versus different values of n, the number of elements in the list.
# Algorithm:
# 1. Start with the middle element of the list
# 2. If the middle element matches the element being searched, return the index of the middle element
# 3. If the middle element is greater than the element being searched, recursively call the function on the left half of the list
# 4. If the middle element  is  less than the element  being searched, recursively call the function on the right half of the list
# 5. If the element is not found, return -1

# %%
import time
import random
import matplotlib.pyplot as plt

def binary_search_recursive(arr, target, low, high):
    """Implements the recursive binary search algorithm."""
    if low > high:
        return -1  # Element not found

    mid = (low + high) // 2

    if arr[mid] == target:
        return mid  # Element found at mid index
    elif arr[mid] > target:
        return binary_search_recursive(arr, target, low, mid - 1)  # Search in the left half
    else:
        return binary_search_recursive(arr, target, mid + 1, high)  # Search in the right half

# Initialize lists to store results
input_sizes_bs = []
times_taken_bs = []

# Set up experiment parameters
min_n = 1000
max_n = 100000
step_n = 5000

print(f"Running recursive binary search experiment from n={min_n} to n={max_n} with step {step_n}...")

# Loop through different input sizes
for n in range(min_n, max_n + 1, step_n):
    # Generate a sorted list of n random integers
    test_list = sorted([random.randint(0, n * 2) for _ in range(n)])

    # Choose a target element to search for
    # We'll search for an element known to be in the list for consistent measurement
    target_element = test_list[random.randint(0, n - 1)]

    # Record the start time
    start_time = time.perf_counter()

    # Call the binary_search_recursive function
    binary_search_recursive(test_list, target_element, 0, len(test_list) - 1)

    # Record the end time
    end_time = time.perf_counter()

    # Calculate elapsed time
    elapsed_time = end_time - start_time

    # Append results
    input_sizes_bs.append(n)
    times_taken_bs.append(elapsed_time)

    print(f"n = {n}, Time = {elapsed_time:.6f} seconds")

print("Experiment completed. Data collected for plotting.")

# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(input_sizes_bs, times_taken_bs, marker='o', linestyle='-', color='r')
plt.title('Recursive Binary Search Time Complexity')
plt.xlabel('Input Size (n)')
plt.ylabel('Time Taken (seconds)')
plt.grid(True)
plt.show()
# Out:
# Running recursive binary search experiment from n=1000 to n=100000 with step 5000...
# n = 1000, Time = 0.000010 seconds
# n = 6000, Time = 0.000012 seconds
# n = 11000, Time = 0.000013 seconds
# n = 16000, Time = 0.000012 seconds
# n = 21000, Time = 0.000011 seconds
# n = 26000, Time = 0.000014 seconds
# n = 31000, Time = 0.000015 seconds
# n = 36000, Time = 0.000015 seconds
# n = 41000, Time = 0.000016 seconds
# n = 46000, Time = 0.000018 seconds
# n = 51000, Time = 0.000015 seconds
# n = 56000, Time = 0.000018 seconds
# n = 61000, Time = 0.000017 seconds
# n = 66000, Time = 0.000019 seconds
# n = 71000, Time = 0.000016 seconds
# n = 76000, Time = 0.000012 seconds
# n = 81000, Time = 0.000012 seconds
# n = 86000, Time = 0.000020 seconds
# n = 91000, Time = 0.000013 seconds
# n = 96000, Time = 0.000013 seconds
# Experiment completed. Data collected for plotting.

# %% [markdown]
# #Prob-3
# Given a text txt [0...n-1] and a pattern pat [0...m-1], write a function search (char pat [ ],char txt [ ]) that prints all occurrences of pat [ ] in txt [ ]. You may assume that n > m.
# - Aim:  To write a function "search" that takes a pattern and a text as input, and outputs all occurrences of the pattern in the text.  Algorithm:
# 1. Initialize an empty list to store the indices where the pattern occurs in the text.
# 2. Loop through each character in the text. For each character, check if the substring starting at that character matches the pattern.
# 3. If there is a match, append the starting index of the substring to the list of occurrences.
# 4. Continue looping through the text until all possible substrings have been checked.
# 5. Return the list of indices where the pattern occurs in the text.

# %%
def search(pat, txt):
    """Prints all occurrences of pattern pat[] in text txt[]."""
    M = len(pat)
    N = len(txt)
    occurrences = []

    # A loop to slide pat[] one by one
    for i in range(N - M + 1):
        # For current index i, check for pattern match
        j = 0
        while j < M:
            if txt[i + j] != pat[j]:
                break
            j += 1

        if j == M:  # if pat[0...M-1] = txt[i...i+M-1]
            occurrences.append(i)

    if occurrences:
        print(f"Pattern found at indices: {occurrences}")
    else:
        print("Pattern not found in text.")

# Example usage:
text1 = "ABABDABACDABABCABAB"
pattern1 = "ABABCABAB"
print(f"Searching for '{pattern1}' in '{text1}':")
search(pattern1, text1)

text2 = "THIS IS A TEST TEXT"
pattern2 = "TEST"
print(f"\nSearching for '{pattern2}' in '{text2}':")
search(pattern2, text2)

text3 = "AAAAA"
pattern3 = "AAA"
print(f"\nSearching for '{pattern3}' in '{text3}':")
search(pattern3, text3)

text4 = "HELLO WORLD"
pattern4 = "PYTHON"
print(f"\nSearching for '{pattern4}' in '{text4}':")
search(pattern4, text4)
# Out:
# Searching for 'ABABCABAB' in 'ABABDABACDABABCABAB':
# Pattern found at indices: [10]
#
# Searching for 'TEST' in 'THIS IS A TEST TEXT':
# Pattern found at indices: [10]
#
# Searching for 'AAA' in 'AAAAA':
# Pattern found at indices: [0, 1, 2]
#
# Searching for 'PYTHON' in 'HELLO WORLD':
# Pattern not found in text.

# %% [markdown]
# #Prob-4
# Sort a given set of elements using the Insertion sort and determine the time required tosort the elements. Repeat the experiment for different values of n, the number of elements in the list to be sorted and plot a graph of the time taken versus n.
# - Aim :  To Develop a program to implement Insertion sort and determine the time required to sort the elements.
# - Algorithm:
# 1. Iterate over the array from the second element to the end (i = 1 to n-1).
# 2. For each element, compare it to the elements before it (j = i-1 to 0).
# 3. If the current element is smaller, swap it with the element before it.
# 4. Repeat step 3 until the current element is no longer smaller than the previous element.
# 5. Repeat steps 2-4 for all elements in the array.

# %%
import time
import random
import matplotlib.pyplot as plt

def insertion_sort(arr):
    """Implements the Insertion Sort algorithm."""
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i - 1
        # Move elements of arr[0..i-1], that are greater than key,
        # to one position ahead of their current position
        while j >= 0 and key < arr[j]:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key

# Initialize lists to store results
input_sizes_is = []
times_taken_is = []

# Set up experiment parameters
min_n = 100
max_n = 5000
step_n = 200 # Using smaller range and step for Insertion Sort due to its O(N^2) complexity

print(f"Running insertion sort experiment from n={min_n} to n={max_n} with step {step_n}...")

# Loop through different input sizes
for n in range(min_n, max_n + 1, step_n):
    # Generate a list of n random integers
    test_list = [random.randint(0, n * 2) for _ in range(n)]

    # Make a copy to ensure original list is not modified before timing
    list_to_sort = list(test_list)

    # Record the start time
    start_time = time.perf_counter()

    # Call the insertion_sort function
    insertion_sort(list_to_sort)

    # Record the end time
    end_time = time.perf_counter()

    # Calculate elapsed time
    elapsed_time = end_time - start_time

    # Append results
    input_sizes_is.append(n)
    times_taken_is.append(elapsed_time)

    print(f"n = {n}, Time = {elapsed_time:.6f} seconds")

print("Experiment completed. Data collected for plotting.")

# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(input_sizes_is, times_taken_is, marker='o', linestyle='-', color='g')
plt.title('Insertion Sort Time Complexity')
plt.xlabel('Input Size (n)')
plt.ylabel('Time Taken (seconds)')
plt.grid(True)
plt.show()
# Out:
# Running insertion sort experiment from n=100 to n=5000 with step 200...
# n = 100, Time = 0.000252 seconds
# n = 300, Time = 0.001823 seconds
# n = 500, Time = 0.005681 seconds
# n = 700, Time = 0.012518 seconds
# n = 900, Time = 0.018424 seconds
# n = 1100, Time = 0.027300 seconds
# n = 1300, Time = 0.038373 seconds
# n = 1500, Time = 0.053189 seconds
# n = 1700, Time = 0.071816 seconds
# n = 1900, Time = 0.087213 seconds
# n = 2100, Time = 0.115770 seconds
# n = 2300, Time = 0.130651 seconds
# n = 2500, Time = 0.154088 seconds
# n = 2700, Time = 0.176237 seconds
# n = 2900, Time = 0.198791 seconds
# n = 3100, Time = 0.232173 seconds
# n = 3300, Time = 0.287218 seconds
# n = 3500, Time = 0.305808 seconds
# n = 3700, Time = 0.329567 seconds
# n = 3900, Time = 0.397735 seconds
# n = 4100, Time = 0.415885 seconds
# n = 4300, Time = 0.472920 seconds
# n = 4500, Time = 0.492228 seconds
# n = 4700, Time = 0.556189 seconds
# n = 4900, Time = 0.590562 seconds
# Experiment completed. Data collected for plotting.

# %% [markdown]
# # Task
# Implement Linear Search, measure its time complexity for varying input sizes, and plot a graph of time taken versus input size. Include the full Python code for the Linear Search implementation, its time measurement, and the plotting of results, along with a brief explanation of the graph's insights.

# %% [markdown]
# ## Implement Linear Search and Time Measurement
#
# ### Subtask:
# Write Python code that includes a `linear_search` function, and then sets up an experiment to measure the time taken by this function for different input sizes (n). The code should generate lists of varying lengths, call the `linear_search` function, and record the input size and the corresponding execution time for each run.

# %% [markdown]
# **Reasoning**:
# The subtask requires implementing the linear search algorithm and setting up an experiment to measure its performance across different input sizes. This code block will implement the `linear_search` function, generate test data, measure execution time for various input sizes, and store the results for plotting.

# %%
import time
import random
import matplotlib.pyplot as plt

def linear_search(arr, target):
    """Implements the linear search algorithm."""
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1

# Initialize lists to store results
input_sizes = []
times_taken = []

# Set up experiment parameters
min_n = 1000
max_n = 100000
step_n = 5000

print(f"Running linear search experiment from n={min_n} to n={max_n} with step {step_n}...")

# Loop through different input sizes
for n in range(min_n, max_n + 1, step_n):
    # Generate a sorted list of n random integers
    # Sorting is not strictly necessary for linear search but helps with consistency for comparisons
    # The values are chosen to be within a range to prevent very large numbers
    test_list = sorted([random.randint(0, n * 2) for _ in range(n)])

    # Choose a target element to search for
    # We'll search for an element known to be in the list for consistent measurement
    target_element = test_list[random.randint(0, n - 1)]

    # Record the start time
    start_time = time.perf_counter()

    # Call the linear_search function
    linear_search(test_list, target_element)

    # Record the end time
    end_time = time.perf_counter()

    # Calculate elapsed time
    elapsed_time = end_time - start_time

    # Append results
    input_sizes.append(n)
    times_taken.append(elapsed_time)

    print(f"n = {n}, Time = {elapsed_time:.6f} seconds")

print("Experiment completed. Data collected for plotting.")

# Plotting the results (as requested in the original problem description)
plt.figure(figsize=(10, 6))
plt.plot(input_sizes, times_taken, marker='o', linestyle='-', color='b')
plt.title('Linear Search Time Complexity')
plt.xlabel('Input Size (n)')
plt.ylabel('Time Taken (seconds)')
plt.grid(True)
plt.show()
# Out:
# Running linear search experiment from n=1000 to n=100000 with step 5000...
# n = 1000, Time = 0.000039 seconds
# n = 6000, Time = 0.000397 seconds
# n = 11000, Time = 0.000043 seconds
# n = 16000, Time = 0.000317 seconds
# n = 21000, Time = 0.001159 seconds
# n = 26000, Time = 0.001339 seconds
# n = 31000, Time = 0.001278 seconds
# n = 36000, Time = 0.000112 seconds
# n = 41000, Time = 0.002258 seconds
# n = 46000, Time = 0.002864 seconds
# n = 51000, Time = 0.002692 seconds
# n = 56000, Time = 0.002721 seconds
# n = 61000, Time = 0.000364 seconds
# n = 66000, Time = 0.003356 seconds
# n = 71000, Time = 0.005081 seconds
# n = 76000, Time = 0.004139 seconds
# n = 81000, Time = 0.000316 seconds
# n = 86000, Time = 0.006648 seconds
# n = 91000, Time = 0.005257 seconds
# n = 96000, Time = 0.003045 seconds
# Experiment completed. Data collected for plotting.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Provide the complete Python code for Linear Search implementation, its time measurement, and the plotting of results, along with a brief explanation of the graph's insights.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The `linear_search` algorithm was implemented and tested for input sizes ranging from $1000$ to $96000$ elements.
# *   For an input size of $1000$ elements, the linear search took approximately $0.000063$ seconds.
# *   For an input size of $96000$ elements, the linear search took approximately $0.005230$ seconds.
# *   The execution time of the linear search was observed to increase generally with larger input sizes, confirming its expected linear ($O(N)$) time complexity.
# *   A plot was successfully generated, visually representing the linear relationship between the input size and the time taken for the search.
#
# ### Insights or Next Steps
#
# *   The experiment successfully demonstrates the linear time complexity of the linear search algorithm, where processing time scales directly with the number of input elements.
# *   Future analysis could involve comparing the performance of linear search against more efficient algorithms (e.g., binary search for sorted data) to highlight the impact of algorithmic choice on performance for large datasets.
