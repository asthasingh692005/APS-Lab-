# %% [markdown]
# <a href="https://colab.research.google.com/github/asthasingh692005/APS-Lab-/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    predecessors = {}
    visited = set()

    for node in graph:
        distances[node] = float('inf')
        predecessors[node] = None

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        if min_node is None: # This can happen if there are unreachable nodes
            break

        visited.add(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                predecessors[neighbor] = min_node

    return distances, predecessors

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10,'C': 3}
}

distances, predecessors = dijkstra(graph, 'A')

print("Shortest paths from source node 'A':")
for node in graph:
    path = reconstruct_path(predecessors, 'A', node)
    if path:
        print(f"  To {node}: Path = {' -> '.join(path)}, Distance = {distances[node]}")
    else:
        print(f"  To {node}: No path found, Distance = {distances[node]}")
# Out:
# Shortest paths from source node 'A':
#   To A: Path = A, Distance = 0
#   To B: Path = A -> B, Distance = 4
#   To C: Path = A -> C, Distance = 2
#   To D: Path = A -> C -> D, Distance = 5

# %%
def reconstruct_path(predecessors, start, end):
    path = []
    current = end
    while current is not None:
        path.insert(0, current)
        current = predecessors[current]
    if path[0] == start:
        return path
    return [] # No path found

# %%
# A more complex graph with additional nodes
graph_extended = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10, 'E': 3},
    'C': {'A': 2, 'B': 5, 'D': 3, 'F': 8},
    'D': {'B': 10, 'C': 3, 'E': 7, 'F': 6},
    'E': {'B': 3, 'D': 7, 'G': 9},
    'F': {'C': 8, 'D': 6, 'G': 1},
    'G': {'E': 9, 'F': 1}
}

# Test with different source nodes and display shortest paths
def test_dijkstra_and_display_paths(graph, source_node):
    distances, predecessors = dijkstra(graph, source_node)
    print(f"\nShortest paths from source node '{source_node}':")
    for node in graph:
        path = reconstruct_path(predecessors, source_node, node)
        if path:
            print(f"  To {node}: Path = {' -> '.join(path)}, Distance = {distances[node]}")
        else:
            print(f"  To {node}: No path found, Distance = {distances[node]}")

test_dijkstra_and_display_paths(graph_extended, 'A')
test_dijkstra_and_display_paths(graph_extended, 'B')
test_dijkstra_and_display_paths(graph_extended, 'F')
# Out:
# Shortest paths from source node 'A':
#   To A: Path = A, Distance = 0
#   To B: Path = A -> B, Distance = 4
#   To C: Path = A -> C, Distance = 2
#   To D: Path = A -> C -> D, Distance = 5
#   To E: Path = A -> B -> E, Distance = 7
#   To F: Path = A -> C -> F, Distance = 10
#   To G: Path = A -> C -> F -> G, Distance = 11
#
# Shortest paths from source node 'B':
#   To A: Path = B -> A, Distance = 4
#   To B: Path = B, Distance = 0
#   To C: Path = B -> C, Distance = 5
#   To D: Path = B -> C -> D, Distance = 8
#   To E: Path = B -> E, Distance = 3
#   To F: Path = B -> C -> F, Distance = 13
#   To G: Path = B -> E -> G, Distance = 12
#
# Shortest paths from source node 'F':
#   To A: Path = F -> C -> A, Distance = 10
#   To B: Path = F -> C -> B, Distance = 13
#   To C: Path = F -> C, Distance = 8
#   To D: Path = F -> D, Distance = 6
#   To E: Path = F -> G -> E, Distance = 10
#   To F: Path = F, Distance = 0
#   To G: Path = F -> G, Distance = 1

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
