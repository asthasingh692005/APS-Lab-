# %% [markdown]
# <a href="https://colab.research.google.com/github/asthasingh692005/APS-Lab-/blob/main/lab_3_growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )

def is_even_or_odd(number):

    return "Even" if number % 2 == 0 else "Odd"

n_values = list(range(1, 101))
time_values = []

for n in n_values:

    is_even_or_odd(n)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Even/Odd Check")
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)

# %%
import matplotlib.pyplot as plt
import random

# Prob_3: Take another example and write the code that runs in linear amount of time or has a fixed number of steps of execution no matter what is the size of input has constant time complexity.
# similar to example-1, also plot the graph (eg. even_odd)

def count_greater_than_zero(numbers):
    count = 0
    for num in numbers:
        if num > 0:
            count += 1
    return count

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    # Create a list of n random numbers for testing
    data = [random.randint(-10, 10) for _ in range(n)]
    count_greater_than_zero(data)
    time_values.append(n) # O(n) complexity, so time is proportional to n

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity for Counting Positive Elements")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.

import math

def binary_search(arr, target):
    low = 0
    high = len(arr) - 1
    steps = 0 # To count operations, representing 'time'

    while low <= high:
        steps += 1
        mid = (low + high) // 2
        if arr[mid] == target:
            return steps # Found, return steps
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return steps # Not found, return steps taken

n_values = list(range(1, 1001, 10))  # Input sizes up to 1000, step of 10
time_values = []

for n in n_values:
    data = sorted(list(range(n))) # Binary search requires sorted data

    if n > 1:
        time_values.append(math.log2(n))
    else:
        time_values.append(0) # For n=0 or n=1, assume constant time (0 or 1 step)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (log n)")
plt.title("O(log n) Logarithmic Time Complexity (Binary Search)")
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.
import math
import random
import matplotlib.pyplot as plt

def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    return merge(left_half, right_half)

def merge(left, right):
    merged = []
    left_idx = 0
    right_idx = 0

    while left_idx < len(left) and right_idx < len(right):
        if left[left_idx] < right[right_idx]:
            merged.append(left[left_idx])
            left_idx += 1
        else:
            merged.append(right[right_idx])
            right_idx += 1

    merged.extend(left[left_idx:])
    merged.extend(right[right_idx:])
    return merged

n_values = list(range(1, 1001, 10))  # Input sizes up to 1000, step of 10
time_values = []

for n in n_values:
    # Simulate O(n log n) behavior by calculating n * log2(n)
    if n > 1:
        time_values.append(n * math.log2(n))
    else:
        time_values.append(0) # For n=0 or n=1, log n is problematic or 0

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (n log n)")
plt.title("O(n log n) Log-Linear Time Complexity (Merge Sort Simulation)")
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in polynomial time (O(n^c)). plot the graph as well, similar to above example.
import matplotlib.pyplot as plt

def find_all_pairs_product(arr):
    count = 0
    for i in arr:
        for j in arr:
            count += i * j # Simulate an O(1) operation inside the nested loop
    return count

n_values = list(range(1, 101))  # Input sizes up to 100
time_values = []

for n in n_values:
    data = list(range(n))
    # Simulate O(n^2) behavior by calculating n**2
    time_values.append(n**2)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (n^2)")
plt.title("O(n^2) Polynomial Time Complexity (Finding All Pairs)")
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in exponential time (O(c^n)). plot the graph as well, similar to above example.
import matplotlib.pyplot as plt

def fibonacci_recursive(n):
    if n <= 1:
        return n
    else:
        return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)

n_values = list(range(1, 21))  # Input sizes up to 20 (exponential grows very fast)
time_values = []

for n in n_values:
    # We'll approximate the time complexity for Fibonacci as roughly proportional to (golden ratio)^n,
    # which is about 1.618^n. Or simply use 2^n for demonstration of exponential growth.
    time_values.append(2**n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (c^n)")
plt.title("O(c^n) Exponential Time Complexity (Fibonacci Simulation)")
plt.yscale('log') # Use a logarithmic scale for the y-axis to better visualize the growth
plt.grid(True)
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure
import matplotlib.pyplot as plt
import numpy as np
import math

n_values = np.arange(1, 60) # A suitable range for n to show all growths, especially exponential

# Calculate time values for each complexity
time_o1 = [1 for _ in n_values]
time_logn = [math.log(n) if n > 0 else 0 for n in n_values]
time_on = n_values
time_nlogn = [n * math.log(n) if n > 0 else 0 for n in n_values]
time_n2 = n_values**2
time_2n = [2**n for n in n_values]

plt.figure(figsize=(12, 8))

plt.plot(n_values, time_o1, label='O(1) - Constant', linestyle='-')
plt.plot(n_values, time_logn, label='O(log n) - Logarithmic', linestyle='-')
plt.plot(n_values, time_on, label='O(n) - Linear', linestyle='-')
plt.plot(n_values, time_nlogn, label='O(n log n) - Log-Linear', linestyle='-')
plt.plot(n_values, time_n2, label='O(n^2) - Polynomial', linestyle='-')
plt.plot(n_values, time_2n, label='O(2^n) - Exponential', linestyle='-')

plt.xlabel("Input size n")
plt.ylabel("Time (Operations)")
plt.title("Comparison of Time Complexities")
plt.legend()
plt.grid(True)
plt.ylim(0, 1000) # Set a y-limit to better visualize the lower complexities before exponential explodes
plt.show()

# %%
# Write a function to perform quick sort and show that it has Logarithmic Time Complexity O(log n)

import matplotlib.pyplot as plt
import numpy as np
import math
import random

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# To simulate O(n log n) for plotting, as Quick Sort's average case is O(n log n)
n_values = np.arange(1, 1001, 10) # Input sizes
time_values = []

for n in n_values:
    # Simulate O(n log n) behavior by calculating n * log2(n)
    if n > 1:
        time_values.append(n * math.log2(n))
    else:
        time_values.append(0) # For n=0 or n=1, log n is problematic or 0

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values, label='O(n log n) - Quick Sort Average Case')
plt.xlabel("Input size n")
plt.ylabel("Time (n log n)")
plt.title("O(n log n) Time Complexity (Quick Sort Simulation)")
plt.legend()
plt.grid(True)
plt.show()
